# %%
# %load_ext autoreload
# %autoreload 3

# %% [markdown]
# ## Running the default model

# %%
from train import train
train()
# Out:
# Epoch (  1 / 30)	 train_loss: 0.89	train_acc (balanced): 0.33		eval_acc (balanced): 0.33
# Epoch (  2 / 30)	 train_loss: 0.80	train_acc (balanced): 0.35		eval_acc (balanced): 0.37
# Epoch (  3 / 30)	 train_loss: 0.79	train_acc (balanced): 0.36		eval_acc (balanced): 0.37
# Epoch (  4 / 30)	 train_loss: 0.78	train_acc (balanced): 0.37		eval_acc (balanced): 0.37
# Epoch (  5 / 30)	 train_loss: 0.77	train_acc (balanced): 0.37		eval_acc (balanced): 0.37
# Epoch (  6 / 30)	 train_loss: 0.77	train_acc (balanced): 0.38		eval_acc (balanced): 0.37
# Epoch (  7 / 30)	 train_loss: 0.76	train_acc (balanced): 0.38		eval_acc (balanced): 0.37
# Epoch (  8 / 30)	 train_loss: 0.76	train_acc (balanced): 0.38		eval_acc (balanced): 0.37
# Epoch (  9 / 30)	 train_loss: 0.76	train_acc (balanced): 0.38		eval_acc (balanced): 0.37
# Epoch ( 10 / 30)	 train_loss: 0.75	train_acc (balanced): 0.38		eval_acc (balanced): 0.37
# ...

# %%
from torch.nn import Sequential, Linear, MaxPool1d, ReLU

input_features = 13
output_calsses = 3
epochs = 100

model = Sequential(*[
    Linear(input_features, 512),
    MaxPool1d(kernel_size=2, stride=2, padding=0),
    ReLU(),
    Linear(256, 3),
    ReLU(),
])

print(model)
train(model, num_epochs=epochs, prefix="")
# Out:
# Sequential(
#   (0): Linear(in_features=13, out_features=1024, bias=True)
#   (1): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (2): ReLU()
#   (3): Linear(in_features=512, out_features=512, bias=True)
#   (4): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (5): ReLU()
#   (6): Linear(in_features=256, out_features=256, bias=True)
#   (7): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (8): ReLU()
#   (9): Linear(in_features=128, out_features=3, bias=True)
#   (10): ReLU()
# )
# Epoch (  1 / 100)	 train_loss: 0.83	train_acc (balanced): 0.34		eval_acc (balanced): 0.37
# Epoch (  2 / 100)	 train_loss: 0.77	train_acc (balanced): 0.36		eval_acc (balanced): 0.37
# Epoch (  3 / 100)	 train_loss: 0.76	train_acc (balanced): 0.37		eval_acc (balanced): 0.37
# Epoch (  4 / 100)	 train_loss: 0.75	train_acc (balanced): 0.38		eval_acc (balanced): 0.37
# ...
