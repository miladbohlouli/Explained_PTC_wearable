# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("data/PTC.csv")

# %%
object_columns = [column for column in dataset.columns if dataset[column].dtype == 'O']

# %%
def convert_nominal(dataset):
    object_columns = [column for column in dataset.columns if dataset[column].dtype == 'O']
    object_columns = object_columns[0]
    dummies = []
    for column in [object_columns]:
        dummies.append(pd.get_dummies(dataset[column]))
        dataset.drop(column, axis=columns)
    dataset = pd.concat([dataset, *dummies], axis=1)
    for column in [object_columns]:

    return dataset

# %%
ds = convert_nominal(dataset)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [94], in <cell line: 1>()
# ----> 1 ds = convert_nominal(dataset)
#
# Input In [93], in convert_nominal(dataset)
#       7 dataset = pd.concat([dataset, *dummies], axis=1)
#       8 for column in [object_columns]:
# ----> 9     dataset.drop("Sex")
#      10 return dataset
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
ds
# Out:
#       ID   Sex  Age  Height  Weight  ColdSens  ColdExp  Workhr  Coffeeintake  \
# 0      3  Male   31    1.70    55.0       3.5      1.6     4.0           0.0
# 1      3  Male   31    1.70    55.0       3.5      1.6     4.0           0.0
# 2      3  Male   31    1.70    55.0       3.5      1.6     4.0           0.0
# 3      3  Male   31    1.70    55.0       3.5      1.6     4.0           0.0
# 4      3  Male   31    1.70    55.0       3.5      1.6     4.0           0.0
# ...   ..   ...  ...     ...     ...       ...      ...     ...           ...
# 3838  12  Male   21    1.75    61.0       3.0      0.0     1.8           0.0
# 3839  12  Male   21    1.75    61.0       3.0      0.0     1.8           0.0
# 3840  12  Male   21    1.75    61.0       3.0      0.0     1.8           0.0
# 3841  12  Male   21    1.75    61.0       3.0      0.0     1.8           0.0
# 3842  12  Male   21    1.75    61.0       3.0      0.0     1.8           0.0
#
# ...
